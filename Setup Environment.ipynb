# %%
# !pip install tensorflow===2.10.0
# !pip install torch
# !pip install keras===2.10.0
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install evaluate
# !pip install nltk
# !pip install rouge_score
# Out:
# Collecting tensorflow===2.10.0
#   Downloading tensorflow-2.10.0-cp39-cp39-macosx_10_14_x86_64.whl (241.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 MB 15.6 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=1.0.0 (from tensorflow===2.10.0)
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow===2.10.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=2.0 (from tensorflow===2.10.0)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow===2.10.0)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow===2.10.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.8 MB/s eta 0:00:00
# Collecting h5py>=2.9.0 (from tensorflow===2.10.0)
#   Downloading h5py-3.10.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (2.5 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow===2.10.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.7 MB/s eta 0:00:00
# Collecting libclang>=13.0.0 (from tensorflow===2.10.0)
#   Downloading libclang-16.0.6-py2.py3-none-macosx_10_9_x86_64.whl.metadata (5.2 kB)
# Collecting numpy>=1.20 (from tensorflow===2.10.0)
#   Using cached numpy-1.26.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata (61 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow===2.10.0)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from tensorflow===2.10.0) (23.1)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow===2.10.0)
#   Downloading protobuf-3.19.6-cp39-cp39-macosx_10_9_x86_64.whl (980 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.5/980.5 kB 38.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from tensorflow===2.10.0) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow===2.10.0)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from tensorflow===2.10.0) (4.7.1)
# Collecting wrapt>=1.11.0 (from tensorflow===2.10.0)
#   Downloading wrapt-1.16.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow===2.10.0)
#   Downloading tensorflow_io_gcs_filesystem-0.34.0-cp39-cp39-macosx_10_14_x86_64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow===2.10.0)
#   Downloading grpcio-1.60.0-cp39-cp39-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow===2.10.0)
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 82.7 MB/s eta 0:00:00a 0:00:01
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow===2.10.0)
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 20.0 MB/s eta 0:00:00
# Collecting keras<2.11,>=2.10.0 (from tensorflow===2.10.0)
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 53.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow===2.10.0) (0.41.2)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading google_auth-2.25.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 70.9 MB/s eta 0:00:00a 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 48.3 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 21.0 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (6.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.11.0)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 19.7 MB/s eta 0:00:00
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.0 MB/s eta 0:00:00
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading grpcio-1.60.0-cp39-cp39-macosx_10_10_universal2.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 81.4 MB/s eta 0:00:0000:0100:01
# Downloading h5py-3.10.0-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 63.5 MB/s eta 0:00:00a 0:00:01
# Downloading libclang-16.0.6-py2.py3-none-macosx_10_9_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 73.2 MB/s eta 0:00:0000:0100:01
# Using cached numpy-1.26.2-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Downloading tensorflow_io_gcs_filesystem-0.34.0-cp39-cp39-macosx_10_14_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.1 MB/s eta 0:00:00
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.16.0-cp39-cp39-macosx_10_9_x86_64.whl (37 kB)
# Downloading google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.2/184.2 kB 24.1 MB/s eta 0:00:00
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 13.8 MB/s eta 0:00:00
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 27.0 MB/s eta 0:00:00
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 10.0 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, libclang, keras, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, requests-oauthlib, pyasn1-modules, opt-einsum, markdown, keras-preprocessing, h5py, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.2 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.25.2 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.60.0 h5py-3.10.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-16.0.6 markdown-3.5.1 numpy-1.26.2 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.34.0 termcolor-2.4.0 werkzeug-3.0.1 wrapt-1.16.0
# Collecting torch
#   Downloading torch-2.1.1-cp39-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from torch) (4.7.1)
# Collecting sympy (from torch)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 37.2 MB/s eta 0:00:0000:0100:01
# Collecting networkx (from torch)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from torch) (3.1.2)
# Collecting fsspec (from torch)
#   Downloading fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from jinja2->torch) (2.1.1)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 29.0 MB/s eta 0:00:00
# Downloading torch-2.1.1-cp39-none-macosx_10_9_x86_64.whl (147.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 MB 45.4 MB/s eta 0:00:0000:0100:01
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 13.5 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.1 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch
# Successfully installed filelock-3.13.1 fsspec-2023.12.2 mpmath-1.3.0 networkx-3.2.1 sympy-1.12 torch-2.1.1
# Requirement already satisfied: keras===2.10.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (2.10.0)
# Collecting transformers
#   Downloading transformers-4.36.0-py3-none-any.whl.metadata (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Using cached huggingface_hub-0.19.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from transformers) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2023.10.3-cp39-cp39-macosx_10_9_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.0-cp39-cp39-macosx_10_7_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.1-cp39-cp39-macosx_10_7_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests->transformers) (2023.11.17)
# Downloading transformers-4.36.0-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 45.2 MB/s eta 0:00:00a 0:00:01
# Using cached huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
# Using cached regex-2023.10.3-cp39-cp39-macosx_10_9_x86_64.whl (296 kB)
# Downloading safetensors-0.4.1-cp39-cp39-macosx_10_7_x86_64.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.6/441.6 kB 38.2 MB/s eta 0:00:00
# Downloading tokenizers-0.15.0-cp39-cp39-macosx_10_7_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 61.6 MB/s eta 0:00:0000:01
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.19.4 regex-2023.10.3 safetensors-0.4.1 tokenizers-0.15.0 tqdm-4.66.1 transformers-4.36.0
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets) (1.26.2)
# Collecting pyarrow>=8.0.0 (from datasets)
#   Downloading pyarrow-14.0.1-cp39-cp39-macosx_10_14_x86_64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting pandas (from datasets)
#   Downloading pandas-2.1.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: requests>=2.19.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets) (4.66.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py39-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2023.10.0,>=2023.1.0 (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets)
#   Using cached fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.9.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from aiohttp->datasets) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Using cached multidict-6.0.4-cp39-cp39-macosx_10_9_x86_64.whl (29 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (31 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Using cached frozenlist-1.4.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->datasets)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from huggingface-hub>=0.18.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from huggingface-hub>=0.18.0->datasets) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from pandas->datasets) (2023.3.post1)
# Collecting tzdata>=2022.1 (from pandas->datasets)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: six>=1.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.8 MB/s eta 0:00:00a 0:00:01
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.9 MB/s eta 0:00:00
# Using cached fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Downloading aiohttp-3.9.1-cp39-cp39-macosx_10_9_x86_64.whl (397 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.9/397.9 kB 27.7 MB/s eta 0:00:00
# Downloading pyarrow-14.0.1-cp39-cp39-macosx_10_14_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 74.0 MB/s eta 0:00:0000:0100:01m
# Downloading multiprocess-0.70.15-py39-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 14.5 MB/s eta 0:00:00
# Downloading pandas-2.1.4-cp39-cp39-macosx_10_9_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 80.2 MB/s eta 0:00:00 0:00:01
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp39-cp39-macosx_10_9_x86_64.whl (31 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached frozenlist-1.4.0-cp39-cp39-macosx_10_9_x86_64.whl (47 kB)
# Downloading yarl-1.9.4-cp39-cp39-macosx_10_9_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.7/83.7 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, tzdata, pyarrow-hotfix, pyarrow, multidict, fsspec, frozenlist, dill, async-timeout, yarl, pandas, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.12.2
#     Uninstalling fsspec-2023.12.2:
#       Successfully uninstalled fsspec-2023.12.2
# Successfully installed aiohttp-3.9.1 aiosignal-1.3.1 async-timeout-4.0.3 datasets-2.15.0 dill-0.3.7 frozenlist-1.4.0 fsspec-2023.10.0 multidict-6.0.4 multiprocess-0.70.15 pandas-2.1.4 pyarrow-14.0.1 pyarrow-hotfix-0.6 tzdata-2023.3 xxhash-3.4.1 yarl-1.9.4
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.4 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: datasets>=2.0.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (2.15.0)
# Requirement already satisfied: numpy>=1.17 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (1.26.2)
# Requirement already satisfied: dill in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (4.66.1)
# Requirement already satisfied: xxhash in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2023.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (0.19.4)
# Requirement already satisfied: packaging in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from evaluate) (23.1)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: filelock in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from pandas->evaluate) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: responses, evaluate
# Successfully installed evaluate-0.4.1 responses-0.18.0
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting click (from nltk)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from nltk) (4.66.1)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.3.2 nltk-3.8.1
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from rouge_score) (2.0.0)
# Requirement already satisfied: nltk in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from rouge_score) (1.26.2)
# Requirement already satisfied: six>=1.14.0 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from nltk->rouge_score) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/pranjalshukla/opt/anaconda3/envs/NLP/lib/python3.9/site-packages (from nltk->rouge_score) (4.66.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24932 sha256=42ec8e34f5bda67178dc4dc48cb392ae64bc1bdc34d388b6f225e8ae9b3e5439
#   Stored in directory: /Users/pranjalshukla/Library/Caches/pip/wheels/9b/3d/39/09558097d3119ca0a4d462df68f22c6f3c1b345ac63a09b86e
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->evaluate) (2022.6)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.3.0
# Collecting nltk
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (2022.10.31)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.3 joblib-1.2.0 nltk-3.7
# Collecting rouge_score
#   Using cached rouge_score-0.1.2-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.23.5)
# Requirement already satisfied: nltk in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (3.7)
# Requirement already satisfied: six>=1.14.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.3.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (4.64.1)
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
